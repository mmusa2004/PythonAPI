# %% [markdown]
# ## WeatherPy

# %% [markdown]
# Observed Analysis
# 1. Temperatures rise as we approach the equator.
# 2. No colerations observed between the relationship of cloudiness and latitude
# 3. Also no relationship between windspeed and latitude

# %%
# Dependencies and Setup
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
from pprint import pprint
import datetime
from citipy import citipy

# Import API key
#from api_keys import api_key

# Insert keys and url 
api_key = "826c70cd546761a184ba2e0e54893073"
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "IMPERIAL"


#------------------------------------



# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generating Cities list

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
#         if len(cities)<100:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ## Perform API Calls

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 2 of set 0 | pulandian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 3 of set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 4 of set 0 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 5 of set 0 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 6 of set 0 | shahrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 7 of set 0 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 8 of set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 9 of set 0 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 10 of set 0 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 11 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 12 of set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 13 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 14 of set 0 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 15 of set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 16 of set 0 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 17 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 18 of set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 19 of set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 20 of set 0 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 21 of set 0 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 22 of set 0 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 23 of set 0 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 24 of set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 25 of set 0 | gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 26 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 27 of set 0 | bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 28 of set 0 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 29 of set 0 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 30 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 31 of set 0 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 32 of set 0 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 33 of set 0 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 34 of set 0 | marataizes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 35 of set 0 | dingzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 36 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 37 of set 0 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 38 of set 0 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 39 of set 0 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 40 of set 0 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 41 of set 0 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 42 of set 0 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 43 of set 0 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 44 of set 0 | anar darreh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 45 of set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 46 of set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 47 of set 0 | abapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 48 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 49 of set 0 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 50 of set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 0 of set 1 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 1 of set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 2 of set 1 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 3 of set 1 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 4 of set 1 | padre paraiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 5 of set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 6 of set 1 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 7 of set 1 | hadishahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 8 of set 1 | iztapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 9 of set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 10 of set 1 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 11 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 12 of set 1 | villa san giovanni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 13 of set 1 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 14 of set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 15 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 16 of set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 17 of set 1 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 18 of set 1 | iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 19 of set 1 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 20 of set 1 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 21 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 22 of set 1 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 23 of set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 24 of set 1 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 25 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 26 of set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 27 of set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 28 of set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 29 of set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 30 of set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 31 of set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 32 of set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 33 of set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 34 of set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 35 of set 1 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 36 of set 1 | sangmelima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 37 of set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 38 of set 1 | champoton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 39 of set 1 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 40 of set 1 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 41 of set 1 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 42 of set 1 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 43 of set 1 | zhob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 44 of set 1 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 45 of set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 46 of set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 47 of set 1 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 48 of set 1 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 49 of set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 50 of set 1 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 0 of set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 1 of set 2 | vilcun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 2 of set 2 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 3 of set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 4 of set 2 | benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 5 of set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 6 of set 2 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 7 of set 2 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 8 of set 2 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 9 of set 2 | mattawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 10 of set 2 | sinop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 11 of set 2 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 12 of set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 13 of set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 14 of set 2 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 15 of set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 16 of set 2 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 17 of set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 18 of set 2 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 19 of set 2 | argelia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 20 of set 2 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 21 of set 2 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 22 of set 2 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 23 of set 2 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 24 of set 2 | xiutetelco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 25 of set 2 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record

# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 45 of set 10 | east stroudsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 46 of set 10 | karkaralinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 47 of set 10 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 48 of set 10 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 49 of set 10 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 50 of set 10 | gladstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 0 of set 11 | medea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 1 of set 11 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 2 of set 11 | mogadouro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 3 of set 11 | wewak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 4 of set 11 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 5 of set 11 | baza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 6 of set 11 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 7 of set 11 | collie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 8 of set 11 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 9 of set 11 | acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 10 of set 11 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 11 of set 11 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 12 of set 11 | lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 13 of set 11 | tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 14 of set 11 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 15 of set 11 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 16 of set 11 | tunceli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 17 of set 11 | maroantsetra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 18 of set 11 | middelburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 19 of set 11 | bonanza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 20 of set 11 | mo i rana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 21 of set 11 | mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 22 of set 11 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 23 of set 11 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 24 of set 11 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 25 of set 11 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 26 of set 11 | singaraja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 27 of set 11 | portoferraio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 28 of set 11 | bako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 29 of set 11 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 30 of set 11 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 31 of set 11 | longkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 32 of set 11 | kuvshinovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 33 of set 11 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 34 of set 11 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 35 of set 11 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 36 of set 11 | desbiens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 37 of set 11 | minusinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# Processing record 38 of set 11 | katsiveli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# Processing record 39 of set 11 | bacuit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=826c70cd546761a184ba2e0e54893073
# City not found!
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          533
# Cloudiness    533
# Country       533
# Date          533
# Humidity      533
# Temp          533
# Lat           533
# Lng           533
# Wind Speed    533
# dtype: int64

# %%
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0       samarai          36      PG  1548867296       100  81.24 -10.62
# 1     pulandian           0      CN  1548865800        17  24.80  39.40
# 2  puerto ayora          40      EC  1548864000        74  84.20  -0.74
# 3         tiksi          56      RU  1548867297         0 -32.34  71.64
# 4        vostok          48      RU  1548867297        55   5.37  46.45
#
#       Lng  Wind Speed
# 0  150.67        9.66
# 1  121.96       13.42
# 2  -90.35       17.22
# 3  128.87       14.81
# 4  135.83        9.22

# %% [markdown]
# ## Create output file, plot graphs and create output Image file for each plot

# %%
cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# Set variable for output file
output_file = os.path.join('output_data', 'cities.csv')
#  Open the output file
with open(output_file, 'w') as datafile:
    weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %%
# Latitude Vs Temperature Plot

weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("Images/LatitudeVsTemperature.png")

# %%
# Latitude Vs Humidity

weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("Images/LatitudeVsHumidity.png")

# %%
# Latitude Vs Cloudiness

weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("Images/LatitudeVsCloudiness.png")

# %%
# Latitude Vs Wind Speed

weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("Images/LatitudeVsWindSpeed.png")
